# %%
import torch

# %%
encode_table = torch.rand((21,2))

# %%
torch.manual_seed(42)
encode_table = torch.rand((21,2))
encode_table[:,1] = encode_table[:, 0]
print(encode_table)
# Out:
# tensor([[0.8823, 0.8823],
#         [0.3829, 0.3829],
#         [0.3904, 0.3904],
#         [0.2566, 0.2566],
#         [0.9408, 0.9408],
#         [0.9346, 0.9346],
#         [0.8694, 0.8694],
#         [0.7411, 0.7411],
#         [0.8854, 0.8854],
#         [0.2666, 0.2666],
#         [0.2696, 0.2696],
#         [0.2969, 0.2969],
#         [0.1053, 0.1053],
#         [0.3588, 0.3588],
#         [0.5472, 0.5472],
#         [0.9516, 0.9516],
#         [0.8860, 0.8860],
#         [0.3376, 0.3376],
#         [0.5779, 0.5779],
#         [0.5547, 0.5547],
#         [0.6343, 0.6343]])
